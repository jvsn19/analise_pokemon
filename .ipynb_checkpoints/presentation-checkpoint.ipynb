# %% [markdown]
# <h1>Pokemon Analysis:</h1>
# <p><a href='https://www.kaggle.com/abcsds/pokemon/downloads/Pokemon.csv/2'>Dataset Link</a></p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from math import pi
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv('Pokemon.csv', index_col='#', )
dataset = dataset.fillna('None')
dataset.head(10)
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                  Bulbasaur  Grass  Poison    318  45      49       49
# 2                    Ivysaur  Grass  Poison    405  60      62       63
# 3                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire    None    309  39      52       43
# 5                 Charmeleon   Fire    None    405  58      64       58
# 6                  Charizard   Fire  Flying    534  78      84       78
# 6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 7                   Squirtle  Water    None    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1       65       65     45           1      False
# 2       80       80     60           1      False
# 3      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 6      130       85    100           1      False
# 6      159      115    100           1      False
# 7       50       64     43           1      False

# %% [markdown]
# <h1>Antes de tudo, qual a distribuição dos tipos de Pokemon?</h1>

# %%
plt.figure(figsize=(15, 7))
plt.subplot(121)
sns.countplot(y = 'Type 1', data = dataset)
plt.subplot(122)
sns.countplot(y = 'Type 2', data = dataset)
plt.show()

# %% [markdown]
# <p>Como podemos ver nos gráficos acima, provavelmente é uma surpresa notar que o tipo de pokemon mais comun é o tipo Aquático. Uma outra análise mostra que o tipo secundário mais comum é o Voador. Além disso podemos notar que o mais comum é existir pokemons com apenas um tipo, vendo que 'Type 2' == None é praticamente a metade do dataset.</p>

# %% [markdown]
# <h1>Distribuição de Atributos</h1>

# %% [markdown]
# <p>Em uma primeira análise podemos pensar "quais são os tipos que tem vantagens em atributos?". Para isso podemos buscar a média de cada atributo agrupado por tipo e gerar gráficos que explorem cada um desses atributos.

# %% [markdown]
# <h3>1. Inicialmente uma visão geral sobre os atributos</h3>

# %%
pokemons = dataset.drop(columns = ['Total', 'Generation', 'Legendary'])
pokemons
# Out:
#                           Name    Type 1  Type 2   HP  Attack  Defense  \
# #
# 1                    Bulbasaur     Grass  Poison   45      49       49
# 2                      Ivysaur     Grass  Poison   60      62       63
# 3                     Venusaur     Grass  Poison   80      82       83
# 3        VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4                   Charmander      Fire    None   39      52       43
# 5                   Charmeleon      Fire    None   58      64       58
# 6                    Charizard      Fire  Flying   78      84       78
# 6    CharizardMega Charizard X      Fire  Dragon   78     130      111
# 6    CharizardMega Charizard Y      Fire  Flying   78     104       78
# 7                     Squirtle     Water    None   44      48       65
# 8                    Wartortle     Water    None   59      63       80
# 9                    Blastoise     Water    None   79      83      100
# 9      BlastoiseMega Blastoise     Water    None   79     103      120
# 10                    Caterpie       Bug    None   45      30       35
# 11                     Metapod       Bug    None   50      20       55
# 12                  Butterfree       Bug  Flying   60      45       50
# 13                      Weedle       Bug  Poison   40      35       30
# 14                      Kakuna       Bug  Poison   45      25       50
# 15                    Beedrill       Bug  Poison   65      90       40
# 15       BeedrillMega Beedrill       Bug  Poison   65     150       40
# 16                      Pidgey    Normal  Flying   40      45       40
# 17                   Pidgeotto    Normal  Flying   63      60       55
# 18                     Pidgeot    Normal  Flying   83      80       75
# 18         PidgeotMega Pidgeot    Normal  Flying   83      80       80
# 19                     Rattata    Normal    None   30      56       35
# 20                    Raticate    Normal    None   55      81       60
# 21                     Spearow    Normal  Flying   40      60       30
# 22                      Fearow    Normal  Flying   65      90       65
# 23                       Ekans    Poison    None   35      60       44
# 24                       Arbok    Poison    None   60      85       69
# ..                         ...       ...     ...  ...     ...      ...
# 700                    Sylveon     Fairy    None   95      65       65
# 701                   Hawlucha  Fighting  Flying   78      92       75
# 702                    Dedenne  Electric   Fairy   67      58       57
# 703                    Carbink      Rock   Fairy   50      50      150
# 704                      Goomy    Dragon    None   45      50       35
# 705                    Sliggoo    Dragon    None   68      75       53
# 706                     Goodra    Dragon    None   90     100       70
# 707                     Klefki     Steel   Fairy   57      80       91
# 708                   Phantump     Ghost   Grass   43      70       48
# 709                  Trevenant     Ghost   Grass   85     110       76
# 710      PumpkabooAverage Size     Ghost   Grass   49      66       70
# 710        PumpkabooSmall Size     Ghost   Grass   44      66       70
# 710        PumpkabooLarge Size     Ghost   Grass   54      66       70
# 710        PumpkabooSuper Size     Ghost   Grass   59      66       70
# 711      GourgeistAverage Size     Ghost   Grass   65      90      122
# 711        GourgeistSmall Size     Ghost   Grass   55      85      122
# 711        GourgeistLarge Size     Ghost   Grass   75      95      122
# 711        GourgeistSuper Size     Ghost   Grass   85     100      122
# 712                   Bergmite       Ice    None   55      69       85
# 713                    Avalugg       Ice    None   95     117      184
# 714                     Noibat    Flying  Dragon   40      30       35
# 715                    Noivern    Flying  Dragon   85      70       80
# 716                    Xerneas     Fairy    None  126     131       95
# 717                    Yveltal      Dark  Flying  126     131       95
# 718           Zygarde50% Forme    Dragon  Ground  108     100      121
# 719                    Diancie      Rock   Fairy   50     100      150
# 719        DiancieMega Diancie      Rock   Fairy   50     160      110
# 720        HoopaHoopa Confined   Psychic   Ghost   80     110       60
# 720         HoopaHoopa Unbound   Psychic    Dark   80     160       60
# 721                  Volcanion      Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed
# #
# 1         65       65     45
# 2         80       80     60
# 3        100      100     80
# 3        122      120     80
# 4         60       50     65
# 5         80       65     80
# 6        109       85    100
# 6        130       85    100
# 6        159      115    100
# 7         50       64     43
# 8         65       80     58
# 9         85      105     78
# 9        135      115     78
# 10        20       20     45
# 11        25       25     30
# 12        90       80     70
# 13        20       20     50
# 14        25       25     35
# 15        45       80     75
# 15        15       80    145
# 16        35       35     56
# 17        50       50     71
# 18        70       70    101
# 18       135       80    121
# 19        25       35     72
# 20        50       70     97
# 21        31       31     70
# 22        61       61    100
# 23        40       54     55
# 24        65       79     80
# ..       ...      ...    ...
# 700      110      130     60
# 701       74       63    118
# 702       81       67    101
# 703       50      150     50
# 704       55       75     40
# 705       83      113     60
# 706      110      150     80
# 707       80       87     75
# 708       50       60     38
# 709       65       82     56
# 710       44       55     51
# 710       44       55     56
# 710       44       55     46
# 710       44       55     41
# 711       58       75     84
# 711       58       75     99
# 711       58       75     69
# 711       58       75     54
# 712       32       35     28
# 713       44       46     28
# 714       45       40     55
# 715       97       80    123
# 716      131       98     99
# 717      131       98     99
# 718       81       95     95
# 719      100      150     50
# 719      160      110    110
# 720      150      130     70
# 720      170      130     80
# 721      130       90     70
#
# [800 rows x 9 columns]

# %% [markdown]
# <h3>1. Separando um dataset com a média de cada atributo agrupado por tipos:</h3>

# %%
attrs = list(dataset)[4:10]
n_attrs = len(attrs)

# %%
sum_by_type1 = dataset.groupby(by = ['Type 1'])[attrs].sum()
sum_by_type2 = dataset.groupby(by = ['Type 2'])[attrs].sum()
count_by_type1 = dataset.groupby(by = ['Type 1'])[attrs].count()
count_by_type2 = dataset.groupby(by = ['Type 2'])[attrs].count()

# %%
mean_by_type = (sum_by_type1 + sum_by_type2)/(count_by_type1 + count_by_type2)
mean_by_type = mean_by_type.drop('None')

# %%
mean_by_type
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def      Speed
# Bug       56.736111   71.763889   71.111111  53.569444  64.666667  61.680556
# Dark      70.235294   96.784314   70.941176  77.450980  69.647059  75.843137
# Dragon    82.900000  105.760000   86.620000  97.440000  86.900000  82.140000
# Electric  63.200000   69.520000   66.540000  88.960000  73.680000  82.940000
# Fairy     68.475000   61.575000   70.400000  76.500000  83.125000  55.850000
# Fighting  74.566038  104.660377   74.056604  66.924528  73.377358  76.528302
# Fire      70.156250   84.109375   70.093750  93.000000  74.328125  75.421875
# Flying    71.366337   80.227723   68.227723  76.366337  71.257426  86.386139
# Ghost     62.826087   76.934783   81.521739  77.478261  76.956522  61.152174
# Grass     66.052632   73.463158   73.252632  72.936842  71.505263  60.715789
# Ground    75.582090   92.671642   87.701493  61.208955  64.835821  59.074627
# Ice       78.631579   82.052632   76.657895  83.105263  79.421053  67.578947
# Normal    76.735294   72.656863   59.607843  57.078431  63.745098  72.245098
# Poison    62.596774   70.790323   63.741935  67.887097  67.419355  65.258065
# Psychic   71.211111   72.644444   74.777778  94.600000  86.766667  77.088889
# Rock      66.017241   90.724138  107.086207  60.396552  73.810345  51.103448
# Steel     64.959184   92.653061  116.612245  72.102041  83.163265  57.102041
# Water     71.023810   73.706349   74.293651  74.777778  70.309524  64.984127

# %% [markdown]
# <p>A partir do dataframe anterior temos a média dos atributos separados por tipos. Para facilitar a visualização, eu projetei um método que plota um gráfico em formato de radar onde cada ponta do mesmo é um atributo. Com esse método é possível gerar esse radar plot com um ou mais tipos</p>

# %%
# Collor palette for each pokemon's type
colors_type = {
    'Bug': '#226022',
    'Dark': '#19164C',
    'Fairy':'#F267A4',
    'Fighting': '#631D1D',
    'Fire': '#F8001D',
    'Flying': '#3B00CD',
    'Ghost': '#670898',
    'Grass': '#1FE300',
    'Ground': '#E47700',
    'Ice': '#0C4D95',
    'Normal': '#7B4848',
    'Poison':'#BC00B4',
    'Psychic': '#B84891',
    'Rock': '#413D5A',
    'Steel': '#666B9D',
    'Water': '#1D9BFB',
    'Dragon': '#895FA9'
}

# %%
# Radar Plot. To plot a radar with multiple types, types_to_analise must have more than one type
def radarPlot(types_to_analise, dataframe, indexes = '111', figsize = (10,7)):        
    attrs = list(dataframe)# The list of attributes to be analised
    n_attrs = len(attrs) # The number of attributes
    angles = [i/float(n_attrs) * 2 * pi for i in range(n_attrs)]
    angles += angles[:1]
    plt.figure(figsize = figsize)
    ax = plt.subplot('111', polar = True)
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    plt.xticks(angles[:-1], attrs, size=8)
    ax.set_rlabel_position(0)
    plt.yticks([25.0, 50.0, 75.0, 100.0], ["25", "50", "75", "100"], size = 7, color="grey")
    plt.ylim(0,130)
    title = ''
    for t in types_to_analise:
        if title == '':
            title += t
        else:
            title += (' x ' + t)
        values = dataframe.loc[t].values.tolist()
        values += values[:1] #Repeat the first value to close the circular graph
        ax.plot(angles, values, linewidth = 1, linestyle = 'solid', color=colors_type[t], label = t)
        ax.fill(angles, values, colors_type[t], alpha=0.3)
        plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    ax.set_title(title)

# %% [markdown]
# <p>Alguma das rivalidades mais fortes no jogo:</p>

# %%
radarPlot(['Psychic', 'Ghost'], mean_by_type)

# %%
radarPlot(['Psychic', 'Fighting'], mean_by_type)

# %%
radarPlot(['Fire', 'Water', 'Grass'], mean_by_type)

# %% [markdown]
# <p>Sobre os 3 tipos de pokemon inicial podemos notar que fogo tem mais vantagem em Velocidade, Ataque Especial e Ataque. Já os pokemons de planta são mais equilibrados, ganhando por pouco em Ataque especial de água. Com essa análise poderíamos optar mais por pokemons de Fogo pois, provavelmente, seria o pokemon inicial mais forte.</p>

# %%
radarPlot(['Steel', 'Rock', 'Fighting'], mean_by_type)

# %% [markdown]
# <p style='color: red'>Um outlier que acabei encontrando enquando analisava o dataframe com as médias: se o usuário preza por uma defesa absurda (tanto física como especial), pokemons de aço são aqueles com a maior defesa do jogo. Comparando com os pokemons de mais "força bruta" (pedra, aço e lutador) notamos a diferença absurda da defesa dos de aço.</p>

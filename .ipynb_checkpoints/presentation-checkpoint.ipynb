# %% [markdown]
# <a href='https://www.pokemon.com/us/'><img src='pokemon-logo.png' width='800px'></a>

# %% [markdown]
# <h1>Introdução</h1>
# <p>Eu pensei muito sobre que dataset iria analisar, inclusive baixei diversos outros sobre terrorismo, porte de arma, viagens de avião, etc. Porém eu comecei a ler um livro sobre "como contar história com dados" e, inicialmente, ele começa motivando ao leitor a pensar em 3 perguntas:</p>
# <ul>
#     <li>Quem? - Para quem você vai apresentar.</li>
#     <li>O quê? - O que você vai apresentar.</li>
#     <li>Como? - Como você vai apresentar.</li>
# </ul>
# <p>Diante dessas perguntas eu pensei que queria apresentar isso de uma forma divertida. Queria falar de um assunto leve e que me deixasse confortável em saber. Claro que o quem é mais relacionado a como eu vou expor as informações, mas pensei também em falar de algo inusitado. Então eu respondi as perguntas depois de procurar mais uns datasets:</p>
# <ul>
#     <li>Quem? - Qualquer pessoa que já ouviu falar de pokemon.</li>
#     <li>O quê? - Vou apresentar uma forma de decidir qual o melhor pokemon, ou o melhor grupo, o melhor tipo.</li>
#     <li>Como? - Tentar mostrar com matemática e gráficos o porquê daquele pokemon ou tipo é o melhor.</li>
# </ul>
# <p><a href='https://www.kaggle.com/abcsds/pokemon/downloads/Pokemon.csv/2'>Dataset</a></p>
# <p><a href='http://www.storytellingwithdata.com/'>Storytelling with Data</a></p>

# %% [markdown]
# <p>Colunas:</p>
# <ul>
#     <li>Name: Nome dos pokemons</li>
#     <li>Type: Os pokemons podem ter até dois tipos, a coluna Type 1 é o tipo principal do pokemon. Type 2 caso o mesmo possua mais de um tipo.</li>
#     <li>Total: Soma de todos os atributos daquele pokemon.</li>
#     <li>HP: Hit Points - Pontos de Vida.</li>
#     <li>Attack: Pontos de Ataque.</li>
#     <li>Defense: Pontos de Defesa.</li>
#     <li>Sp. Atk: Special Attack - Pontos de Ataque Especial (ataques psíquicos, elementais)</li>
#     <li>Sp. Def: Special Defense - Pontos de Defesa Especial</li>
#     <li>Speed: Velocidade (decide que pokemon ataca primeiro)</li>
#     <li>Generation: Geração daquele pokemon</li>
#     <li>Legendary: Lendário</li>
# </ul>

# %%
# Collor palette for each pokemon's type
colors_type = {
    'Bug': '#226022',
    'Dark': '#19164C',
    'Dragon': '#895FA9',
    'Electric': '#FFEC02',
    'Fairy':'#F267A4',
    'Fighting': '#631D1D',
    'Fire': '#F8001D',
    'Flying': '#3B00CD',
    'Ghost': '#670898',
    'Grass': '#1FE300',
    'Ground': '#E47700',
    'Ice': '#0C4D95',
    'Normal': '#7B4848',
    'Poison':'#BC00B4',
    'Psychic': '#B84891',
    'Rock': '#413D5A',
    'Steel': '#666B9D',
    'Water': '#1D9BFB'
}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns
import numpy as np
import warnings
from math import pi
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv('Pokemon.csv')
dataset = dataset.drop(columns = ['#']) # a coluna '#' não isola bem os pokemons, visto que alguns valores se repetem
dataset.Name.replace(re.compile("^.*Mega"), "Mega", inplace=True) # Removendo nomes repetidos nas evoluções Mega
dataset.head()
# Out:
#             Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1        Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2       Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# 4     Charmander   Fire     NaN    309  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
attrs = list(dataset)[4:10]
n_attrs = len(attrs)
types = list(dataset['Type 1'].unique())
generations = list(dataset['Generation'].unique())
print("Atributos:")
for attr in attrs:
    print("\t" + attr)
print("Tipos de Pokemons:")
for t in types:
    print("\t" + t)
# Out:
# Atributos:
# 	HP
# 	Attack
# 	Defense
# 	Sp. Atk
# 	Sp. Def
# 	Speed
# Tipos de Pokemons:
# 	Grass
# 	Fire
# 	Water
# 	Bug
# 	Normal
# 	Poison
# 	Electric
# 	Ground
# 	Fairy
# 	Fighting
# 	Psychic
# 	Rock
# 	Ghost
# 	Ice
# 	Dragon
# 	Dark
# 	Steel
# 	Flying

# %% [markdown]
# <h1>1. Uma análise mais específica: Pokemons</h1>

# %% [markdown]
# <p>Inicialmente podemos fazer uma análise por atributos de pokemons. É normal alguns jogadores quererem os pokemons mais ataque, defesa, etc.</p>

# %% [markdown]
# <h3>1.1 Distribuição de Atributos</h3>

# %% [markdown]
# <p>Em uma primeira análise podemos pensar "quais são os tipos que tem vantagens em atributos?". Para isso podemos buscar a média de cada atributo agrupado por tipo e gerar gráficos que explorem cada um desses atributos.

# %%
# Criando um dataframe "pokemons" que mostra apenas os pokemons e seus status
pokemons = dataset.drop(columns = ['Total', 'Generation', 'Legendary'])
pokemons_notLendary = dataset[dataset['Legendary'] == False].drop(columns = ['Total', 'Generation', 'Legendary'])

# %%
plt.figure(figsize = (16,7))
ax = sns.boxplot(data=pokemons)
ax.set_title('Box Plot of Attributes')
plt.show()

# %% [markdown]
# <p>Aqui notamos como cada atributo se comporta. Notamos principalmente o número de outliers dos atributos HP e Defesa; principalmente HP, onde os dados são distribuidos "normalmente", mas o excesso de outliers mostra que esse é um atributo mais inconstante (HP acima de 200 são os outliers mais chamativos).</p>

# %% [markdown]
# <h3>1.2 Encontrando os Outliers</h3>

# %% [markdown]
# <p>Como visto anteriormente, vários atributos possuem muitos outliers, especialmente o HP. Então começamos buscando quem são esses pokemons.</p>
# <p style="color:red">OBS: em algumas análises muitos desses "top pokemons" são lendários, então preferi excluí-los. Adiante terá uma análise dos pokemons raros.</p>

# %%
# Método para retornar um dataset com o top x pokemons, onde x é definido pelo usuário, baseado em atributos
# É possível também não priorizar lendários
# É possível também filtrar em apenas lendários ou não
def findTopByAttr(dataframe, attrs, legendaryPriority = True, top = 5, 
                  filterLegendary = None, filterMega = None, filterMode = None):
    toQuery = dataframe
    if filterLegendary != None:
        toQuery = toQuery[dataframe['Legendary'] == filterLegendary]
    mask_ascending = list(np.zeros_like(attrs, dtype=np.bool))
    if filterMega != None:
        # Criei uma lambda function para filtrar apenas pokemon sem o nome Mega para limpar algumas consultas
        toQuery = toQuery[lambda df: [not (filterMega ^ bool(re.search('^(Mega)', name))) for name in df['Name']]]
    if filterMode != None:
        toQuery = toQuery[lambda df: [not (filterMode ^ bool(re.search('(Mode$)', name))) for name in df['Name']]]
    if legendaryPriority:
        attrs = ['Legendary'] + attrs
        mask_ascending = [True] + mask_ascending
    top_dataframe = toQuery.sort_values(by= attrs, ascending=mask_ascending).head(top)
    return top_dataframe

# %% [markdown]
# <h4>Pokemons Normais:</h4>

# %% [markdown]
# <h5>Top 5 HP:</h5>

# %%
findTopByAttr(dataset, ['HP'], filterMega=False)
# Out:
#           Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261    Blissey   Normal    NaN    540  255      10       10       75      135
# 121    Chansey   Normal    NaN    450  250       5        5       35      105
# 217  Wobbuffet  Psychic    NaN    405  190      33       58       33       58
# 351    Wailord    Water    NaN    500  170      90       45       90       45
# 655  Alomomola    Water    NaN    470  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 261     55           2      False
# 121     50           1      False
# 217     33           2      False
# 351     60           3      False
# 655     65           5      False

# %%
findTopByAttr(dataset, ['Attack'], filterMega = False)
# Out:
#                      Name  Type 1 Type 2  Total   HP  Attack  Defense  \
# 454             Rampardos    Rock    NaN    495   97     165       60
# 313               Slaking  Normal    NaN    670  150     160      100
# 750  AegislashBlade Forme   Steel  Ghost    520   60     150       50
# 673               Haxorus  Dragon    NaN    540   76     147       90
# 515             Rhyperior  Ground   Rock    535  115     140      130
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 454       65       50     58           4      False
# 313       95       65    100           3      False
# 750      150       50     60           6      False
# 673       60       70     97           5      False
# 515       55       55     40           4      False

# %%
findTopByAttr(dataset, ['Defense'], filterMega = False)
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230   Shuckle    Bug    Rock    505  20      10      230       10      230
# 223   Steelix  Steel  Ground    510  75      85      200       55       65
# 789   Avalugg    Ice     NaN    514  95     117      184       44       46
# 98   Cloyster  Water     Ice    525  50      95      180       85       45
# 332    Aggron  Steel    Rock    530  70     110      180       60       60
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 223     30           2      False
# 789     28           6      False
# 98      70           1      False
# 332     50           3      False

# %%
findTopByAttr(dataset, ['Sp. Atk'], filterMega = False, filterMode = False)
# Out:
#                      Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 750  AegislashBlade Forme    Steel  Ghost    520  60     150       50
# 670            Chandelure    Ghost   Fire    520  60      55       90
# 70               Alakazam  Psychic    NaN    500  55      50       45
# 525             Porygon-Z   Normal    NaN    535  85      80       70
# 698             Volcarona      Bug   Fire    550  85      60       65
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 750      150       50     60           6      False
# 670      145       90     80           5      False
# 70       135       95    120           1      False
# 525      135       75     90           4      False
# 698      135      105    100           5      False

# %%
findTopByAttr(dataset, ['Sp. Def'], filterMega = False)
# Out:
#                       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 230                Shuckle    Bug   Rock    505  20      10      230       10
# 739                Florges  Fairy    NaN    552  78      65       68      112
# 528              Probopass   Rock  Steel    525  60      55      145       75
# 751  AegislashShield Forme  Steel  Ghost    520  60      50      150       50
# 773                Carbink   Rock  Fairy    500  50      50      150       50
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 739      154     75           6      False
# 528      150     40           4      False
# 751      150     60           6      False
# 773      150     50           6      False

# %%
findTopByAttr(dataset, ['Speed'], filterMega = False)
# Out:
#            Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 315     Ninjask       Bug  Flying    456  61      90       45       50
# 678    Accelgor       Bug     NaN    495  80      70       40      100
# 109   Electrode  Electric     NaN    480  60      50       70       80
# 146     Jolteon  Electric     NaN    525  65      65       60      110
# 153  Aerodactyl      Rock  Flying    515  80     105       65       60
#
#      Sp. Def  Speed  Generation  Legendary
# 315       50    160           3      False
# 678       60    145           5      False
# 109       80    140           1      False
# 146       95    130           1      False
# 153       75    130           1      False

# %%
findTopByAttr(dataset, ['Total'], filterMega = False)
# Out:
#           Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 313    Slaking   Normal     NaN    670  150     160      100       95
# 161  Dragonite   Dragon  Flying    600   91     134       95      100
# 165        Mew  Psychic     NaN    600  100     100      100      100
# 267  Tyranitar     Rock    Dark    600  100     134      110       95
# 271     Celebi  Psychic   Grass    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# 313       65    100           3      False
# 161      100     80           1      False
# 165      100    100           1      False
# 267      100     61           2      False
# 271      100    100           2      False

# %% [markdown]
# <p>A partir das queries acima temos os 5 maiores outliers de cada atributo (excluindo as formas Mega e os Lendário). A partir dessas tabelas já podemos ter algumas ideias de pokemons que podemos escolher para o time.</p>
# <ul>
#     <li>Alakazam é um pokemon da primeira geração com um poderoso Ataque Especial e com HP, Velocidade e Defesa Especial interessantemente altos</li>
#     <li>Para possuir um pokemon de "recuperação", Blissey possui o maior HP do jogo (de longe, junto com sua pré-evolução) e uma boa Defesa Especial. Só é preciso ter cuidado com pokemons de Ataque Físico</li>
#     <li>Steelix é uma ótima opção de Defesa, além de possuir os outros atributos relativamente equilibrados.</li>
# </ul>
# <p style="color:red">OBS: Mode e Mega foram retirados. Forme foi mantido por ser uma característica do pokemon.</p>

# %% [markdown]
# <h4>Adicionando Pokemons Lendários:</h4>

# %%
findTopByAttr(dataset, ['HP'], legendaryPriority=False ,filterMega = False)
# Out:
#           Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261    Blissey   Normal    NaN    540  255      10       10       75      135
# 121    Chansey   Normal    NaN    450  250       5        5       35      105
# 217  Wobbuffet  Psychic    NaN    405  190      33       58       33       58
# 351    Wailord    Water    NaN    500  170      90       45       90       45
# 655  Alomomola    Water    NaN    470  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 261     55           2      False
# 121     50           1      False
# 217     33           2      False
# 351     60           3      False
# 655     65           5      False

# %%
findTopByAttr(dataset, ['Attack'], legendaryPriority=False ,filterMega = False)
# Out:
#                       Name   Type 1 Type 2  Total   HP  Attack  Defense  \
# 424  GroudonPrimal Groudon   Ground   Fire    770  100     180      160
# 429     DeoxysAttack Forme  Psychic    NaN    600   50     180       20
# 711     KyuremBlack Kyurem   Dragon    Ice    700  125     170      100
# 454              Rampardos     Rock    NaN    495   97     165       60
# 313                Slaking   Normal    NaN    670  150     160      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 424      150       90     90           3       True
# 429      180       20    150           3       True
# 711      120       90     95           5       True
# 454       65       50     58           4      False
# 313       95       65    100           3      False

# %%
findTopByAttr(dataset, ['Defense'], legendaryPriority=False ,filterMega = False)
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230   Shuckle    Bug    Rock    505  20      10      230       10      230
# 414  Regirock   Rock     NaN    580  80     100      200       50      100
# 223   Steelix  Steel  Ground    510  75      85      200       55       65
# 789   Avalugg    Ice     NaN    514  95     117      184       44       46
# 332    Aggron  Steel    Rock    530  70     110      180       60       60
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 414     50           3       True
# 223     30           2      False
# 789     28           6      False
# 332     50           3      False

# %%
findTopByAttr(dataset, ['Sp. Atk'], legendaryPriority=False ,filterMega = False)
# Out:
#                     Name   Type 1 Type 2  Total   HP  Attack  Defense  \
# 429   DeoxysAttack Forme  Psychic    NaN    600   50     180       20
# 422  KyogrePrimal Kyogre    Water    NaN    770  100     150       90
# 798   HoopaHoopa Unbound  Psychic   Dark    680   80     160       60
# 712   KyuremWhite Kyurem   Dragon    Ice    700  125     120       90
# 162               Mewtwo  Psychic    NaN    680  106     110       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 429      180       20    150           3       True
# 422      180      160     90           3       True
# 798      170      130     80           6       True
# 712      170      100     95           5       True
# 162      154       90    130           1       True

# %%
findTopByAttr(dataset, ['Sp. Def'], legendaryPriority=False ,filterMega = False)
# Out:
#                     Name   Type 1 Type 2  Total   HP  Attack  Defense  \
# 230              Shuckle      Bug   Rock    505   20      10      230
# 415               Regice      Ice    NaN    580   80      50      100
# 430  DeoxysDefense Forme  Psychic    NaN    600   50      70      160
# 422  KyogrePrimal Kyogre    Water    NaN    770  100     150       90
# 739              Florges    Fairy    NaN    552   78      65       68
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230       10      230      5           2      False
# 415      100      200     50           3       True
# 430       70      160     90           3       True
# 422      180      160     90           3       True
# 739      112      154     75           6      False

# %%
findTopByAttr(dataset, ['Speed'], legendaryPriority=False ,filterMega = False)
# Out:
#                    Name   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 431   DeoxysSpeed Forme  Psychic     NaN    600  50      95       90       95
# 315             Ninjask      Bug  Flying    456  61      90       45       50
# 429  DeoxysAttack Forme  Psychic     NaN    600  50     180       20      180
# 428  DeoxysNormal Forme  Psychic     NaN    600  50     150       50      150
# 678            Accelgor      Bug     NaN    495  80      70       40      100
#
#      Sp. Def  Speed  Generation  Legendary
# 431       90    180           3       True
# 315       50    160           3      False
# 429       20    150           3       True
# 428       50    150           3       True
# 678       60    145           5      False

# %%
findTopByAttr(dataset, ['Total'], legendaryPriority=False ,filterMega = False, top = 20)
# Out:
#                       Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 424  GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# 422    KyogrePrimal Kyogre    Water       NaN    770  100     150       90
# 552                 Arceus   Normal       NaN    720  120     120      120
# 712     KyuremWhite Kyurem   Dragon       Ice    700  125     120       90
# 711     KyuremBlack Kyurem   Dragon       Ice    700  125     170      100
# 544  GiratinaAltered Forme    Ghost    Dragon    680  150     100      120
# 545   GiratinaOrigin Forme    Ghost    Dragon    680  150     120      100
# 541                 Palkia    Water    Dragon    680   90     120      100
# 540                 Dialga    Steel    Dragon    680  100     120      120
# 425               Rayquaza   Dragon    Flying    680  105     150       90
# 706               Reshiram   Dragon      Fire    680  100     120      100
# 707                 Zekrom   Dragon  Electric    680  100     150      120
# 792                Xerneas    Fairy       NaN    680  126     131       95
# 269                  Lugia  Psychic    Flying    680  106      90      130
# 798     HoopaHoopa Unbound  Psychic      Dark    680   80     160       60
# 270                  Ho-oh     Fire    Flying    680  106     130       90
# 162                 Mewtwo  Psychic       NaN    680  106     110       90
# 793                Yveltal     Dark    Flying    680  126     131       95
# 423                Groudon   Ground       NaN    670  100     150      140
# 421                 Kyogre    Water       NaN    670  100     100       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 424      150       90     90           3       True
# 422      180      160     90           3       True
# 552      120      120    120           4       True
# 712      170      100     95           5       True
# 711      120       90     95           5       True
# 544      100      120     90           4       True
# 545      120      100     90           4       True
# 541      150      120    100           4       True
# 540      150      100     90           4       True
# 425      150       90     95           3       True
# 706      150      120     90           5       True
# 707      120      100     90           5       True
# 792      131       98     99           6       True
# 269       90      154    110           2       True
# 798      170      130     80           6       True
# 270      110      154     90           2       True
# 162      154       90    130           1       True
# 793      131       98     99           6       True
# 423      100       90     90           3       True
# 421      150      140     90           3       True

# %% [markdown]
# <p>Sendo essa última apenas uma tabela confirmativa, os pokemons lendários detêm as maiores somas de atributos</p>

# %% [markdown]
# <p>Com essas tabelas a seguir é possível pensar em quais pokemons escolher observando esses atributos. Adicionando pokemons lendários também nos dá a chance de comparar esses pokemons com os de nível lendário.Por exemplo:</p>
# <ul>
#     <li>Blissey e Chansey conseguem superar todos os lendários (estes nem aparecem na tabela).</li>
#     <li>Ninjask perde em Velocidade apenas para Deoxys na sua forma de velocidade (porém os outros atributos deixam a desejar. </li>
# </ul>

# %% [markdown]
# <h3>1.3 Comparação dentro dos Top 5 não lendários</h3>

# %% [markdown]
# <p>Vendo os atributos absurdos desses outliers nos faz pensar se vale muito a pena ter esses pokemons. Então aqui vai uma análise entre os pokemons de alguns Top 5.</p>
# <p style="color:red">OBS: Não lendários pois é um pouco injusto comparar com lendários.</p>

# %%
# Método que fiz baseado no radarPlot abaixo.
def radarPlotPokemons(pokemons, dataframe, figsize = (10,7)): 
    features= ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
    # Numero de features
    n_features = len(features)
    # Ângulos a partir do eixo x de cada feature
    angles = [i/float(n_features) * 2 * pi for i in range(n_features)]
    angles.append(angles[0]) # Eu devo repetir o primeiro ângulo para fechar o polígono dentro do gráfico
    plt.figure(figsize = figsize)
    ax = plt.subplot('111', polar = True)
    # Girar o gráfico 90º no sentido anti-horário
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    # Colocar o nome das features
    plt.xticks(angles[:-1], features, size=8)
    ax.set_rlabel_position(0)
    # Colocando linhas para mapear valores no eixo y (no caso temos eixos polares)
    plt.yticks([50.0, 100.0, 150.0, 200.0], ["50", "100", "150", "200"], size = 7, color="grey")
    plt.ylim(0,250)
    # Título do gráfico
    title = ''
    for t in pokemons:
        if title == '':
            title += t
        else:
            title += (' x ' + t)
        # values guardará os valores das features da linha "t"
        values = dataframe[dataframe['Name'] == t][features].values.tolist()[0]
        values.append(values[0]) # Assim como nos ângulos, repetimos aqui para fechar o polígono
        # Plotando as linhas
        ax.plot(angles, values, linewidth = 1, linestyle = 'solid', label=t)
        # Pintando a área interna do polígono
        ax.fill(angles, values, alpha=0.3)
        # Inserindo legendas
        plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    ax.set_title(title)

# %%
radarPlotPokemons(pokemons=['Blissey', 'Alomomola', 'Wailord'], dataframe = pokemons)

# %% [markdown]
# <p>Observando 3 pokemons do top 5 HP, vemos que a Blissey é bem superior no HP, porém perde para os outros dois em Ataque e Defesa.</p>

# %%
radarPlotPokemons(pokemons=['Ninjask', 'Jolteon', 'Electrode'], dataframe = pokemons)

# %% [markdown]
# <p>Repetindo mais uma vez o mesmo teste anterior, agora focando em Velocidade, vemos um exemplo em que um pokemon possui muita vantagem em velocidade se comparando com outros top 5, porém perde em Ataque Especial, Defesa Especial e Defesa</p>

# %% [markdown]
# <h3>1.4 Conclusão</h3>
# <p>Como vimos em algumas comparações, as vezes não vale tanto a pena pegar o melhor pokemon em um atributo pois o mesmo perde muito em outros. Existem bons pokemons outliers, mas talvez uma análise mais aprofundada seja necessária para fechar o time.</p>

# %% [markdown]
# <h2>2. Buscando uma relação entre os atributos</h2>

# %% [markdown]
# <p>Após notar a falta de atributos em alguns pokemons podemos pensar se existe uma relação entre atributos. Se existe, por exemplo, uma relação entre pokemons com alto Ataque e Defesa, Ataque Especial e Defesa Especial.</p>

# %% [markdown]
# <h3>2.1 Matriz de Correlação Entre Atributos</h3>

# %% [markdown]
# <p>Matriz de correlação é uma matriz que mede a correlação entre atributos de uma tabela. Quanto mais próximo (correlacionado) um atributo for de um, mais próximo o valor entre eles é de 1.0. Se o valor for próximo de -1.0, esses atributos são opostos (enquanto um cresce, o outro decresce).</p>

# %%
# Criando uma matriz de correlação dos atributos de cada pokemon
corr_matrix = pokemons.corr()
# Criando uma máscara para a matriz de correlação. A mesma é triangular, então nos interessa apenas metade da matriz
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
plt.figure(figsize=(10,7))
cmap = sns.diverging_palette(220, 10, s = 99, l = 30, as_cmap=True)
ax = sns.heatmap(corr_matrix, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
ax.set_title('Correlation Matrix of Attributes')
plt.show()

# %% [markdown]
# <p>Como é possível imaginar, não existe uma correlação ~1.0 entre os atributos, mas podemos notar um certo grau de correlação entre os atributos: Defesa Especial e Defesa, Defesa Especial, Ataque Especial e Ataque e HP.</p>
# <p>Supondo uma boa correlação aquela > 0.4:</p>
# <ul>
#     <li>Pokemons focados em Defesa Especial podem possuir um bom Ataque Especial e Defesa.</li>
#     <li>Pokemons focados em Ataque físico podem possuir uma boa Defesa e HP</li>
#     <li>Pokemons focados em Ataque Especial podem possuir uma boa Velocidade</li>
# </ul>

# %% [markdown]
# <h2>2.2 Conclusão</h2>
# <p>Olhando só os atributos em si não é uma boa forma de buscar os melhores pokemons. Claro que, a partir do que foi exposto, é possível pensar em um tipo de pokemon que consiga focar em mais de um atributo (o que foi o caso dos pokemons com boa Defesa Especial).</p>

# %% [markdown]
# <h2>3. Pokemons Semelhantes</h2>

# %% [markdown]
# <p>Alguns pokemons podem ser considerados semelhantes: semelhança por tipo, força, defesa. Uma possível estratégia é tentar unificar um time de um tipo só ou variar o máximo possível.</p>

# %% [markdown]
# <h3>3.1 Tipos de Pokemons</h3>
# <p>Como vimos anteriormente, os pokemons são divididos em tipos. Além disso cada pokemon pode possuir um ou dois tipos. Uma análise que pode ser feita sobre isso é saber quais os tipos mais comuns e analisar vantagens e desvantagens de cada tipo.</p>
# <img src='types_pkmn.png' width='650px'>
# <p>A partir disso podemos iniciar uma estratégia onde buscamos os pokemons com mais chances de ganhar vantagens ou pokemons com menos chances de sofrer desvantagens</p>

# %%
count_types = dataset['Type 1'].value_counts() + dataset['Type 2'].value_counts()

# %%
plt.figure(figsize=(10,10))
colors_aux = colors_type.values()
ax = plt.subplot(111)
plt.pie(x = count_types, labels = types, autopct='%1.1f%%', colors=colors_aux, shadow=True)
plt.title('Pie of Pokemon Types')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.subplot(121)
sns.countplot(y = 'Type 1', data = dataset, palette=colors_type)
plt.subplot(122)
sns.countplot(y = 'Type 2', data = dataset, palette=colors_type)
plt.show()

# %% [markdown]
# <p>Como podemos ver nos gráficos acima, provavelmente é uma surpresa notar que o tipo de pokemon mais comun é o tipo Aquático. Uma outra análise mostra que o tipo secundário mais comum é o Voador.</p>
# <p>Alguns insights:</p>
# <ul>
#     <li>Como a maioria dos pokemons são do tipo água, os mesmo do tipo Elétrico, e Grama possuem uma vantagem estatística. É mais provável que um jogador enfrente mais pokemons aquáticos.</li>
#     <li>Pokemons voadores são bem mais frequentes no segundo tipo. Analisando isso podemos dizer que uma grande parte dos pokemons são também do tipo voador, dando vantagem a pokemons do tipo elétrico.</li>
# </ul>
# <p>Porém esse tipo de estratégia não funciona bem com jogadores que tentam variar o máximo o tipo de seus pokemons. Então uma outra abordagem não é só olhar para as vantagens e desvantagens, mas o também no que aquele tipo de pokemon pode me retornar.</p>

# %% [markdown]
# <h3>3.2 Análise dos Atributos por Tipo:</h3>

# %%
# Para analisar ambos Type 1 e Type 2:
# Primeiro agrupei o dataset por tipos e somei todos os atributos
sum_by_type1 = dataset.groupby(by = ['Type 1'])[attrs].sum()
sum_by_type2 = dataset.groupby(by = ['Type 2'])[attrs].sum()
# Fiz mais dois datasets agrupados por tipos e contei quantas aparições aquele atributo possui
count_by_type1 = dataset.groupby(by = ['Type 1'])[attrs].count()
count_by_type2 = dataset.groupby(by = ['Type 2'])[attrs].count()
# Com a soma e o número de aparições, somei os dataframes de soma e dividi pela soma do dataframe de frequência,
# gerando a média por atributo.
mean_by_type = (sum_by_type1 + sum_by_type2)/(count_by_type1 + count_by_type2)

# %%
mean_by_type
# Out:
#                  HP      Attack     Defense    Sp. Atk    Sp. Def      Speed
# Type 1
# Bug       56.736111   71.763889   71.111111  53.569444  64.666667  61.680556
# Dark      70.235294   96.784314   70.941176  77.450980  69.647059  75.843137
# Dragon    82.900000  105.760000   86.620000  97.440000  86.900000  82.140000
# Electric  63.200000   69.520000   66.540000  88.960000  73.680000  82.940000
# Fairy     68.475000   61.575000   70.400000  76.500000  83.125000  55.850000
# Fighting  74.566038  104.660377   74.056604  66.924528  73.377358  76.528302
# Fire      70.156250   84.109375   70.093750  93.000000  74.328125  75.421875
# Flying    71.366337   80.227723   68.227723  76.366337  71.257426  86.386139
# Ghost     62.826087   76.934783   81.521739  77.478261  76.956522  61.152174
# Grass     66.052632   73.463158   73.252632  72.936842  71.505263  60.715789
# Ground    75.582090   92.671642   87.701493  61.208955  64.835821  59.074627
# Ice       78.631579   82.052632   76.657895  83.105263  79.421053  67.578947
# Normal    76.735294   72.656863   59.607843  57.078431  63.745098  72.245098
# Poison    62.596774   70.790323   63.741935  67.887097  67.419355  65.258065
# Psychic   71.211111   72.644444   74.777778  94.600000  86.766667  77.088889
# Rock      66.017241   90.724138  107.086207  60.396552  73.810345  51.103448
# Steel     64.959184   92.653061  116.612245  72.102041  83.163265  57.102041
# Water     71.023810   73.706349   74.293651  74.777778  70.309524  64.984127

# %% [markdown]
# <p>A partir do dataframe com a média dos atributos por tipo podemos buscar, para cada atributo, qual o tipo mais forte.</p>

# %%
max_indexes = {attr: mean_by_type[attr].idxmax() for attr in attrs}
max_indexes
# Out:
# {'Attack': 'Dragon',
#  'Defense': 'Steel',
#  'HP': 'Dragon',
#  'Sp. Atk': 'Dragon',
#  'Sp. Def': 'Dragon',
#  'Speed': 'Flying'}

# %% [markdown]
# <p>Por fim, Dragão é o tipo com maior vantagem no jogo, sendo uma ótima escolha buscar esses pokemons.</p>

# %% [markdown]
# <p>A partir do dataframe anterior temos a média dos atributos separados por tipos. Para facilitar a visualização, eu projetei um método que gera um gráfico em formato de radar onde cada ponta do mesmo é um atributo. Com esse método é possível gerar esse radar plot com um ou mais tipos.</p>

# %%
def radarPlot(types_to_analise, dataframe, figsize = (10,7)):        
    # Lista com features a serem analisadas
    attrs = list(dataframe)
    # Numero de features
    n_attrs = len(attrs) 
    # Ângulos a partir do eixo x de cada feature
    angles = [i/float(n_attrs) * 2 * pi for i in range(n_attrs)]
    angles.append(angles[0])
    plt.figure(figsize = figsize)
    ax = plt.subplot('111', polar = True)
    # Girar o gráfico 90º no sentido anti-horário
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    # Colocar o nome das features
    plt.xticks(angles[:-1], attrs, size=8)
    ax.set_rlabel_position(0)
    # Colocando linhas para mapear valores no eixo y (no caso temos eixos polares)
    plt.yticks([25.0, 50.0, 75.0, 100.0], ["25", "50", "75", "100"], size = 7, color="grey")
    plt.ylim(0,130)
    # Título do gráfico
    title = ''
    for t in types_to_analise:
        if title == '':
            title += t
        else:
            title += (' x ' + t)
        # values guardará os valores das features da linha "t"
        values = dataframe.loc[t].values.tolist()
        values += values[:1] # Assim como nos ângulos, repetimos aqui para fechar o polígono
        # Plotando as linhas
        ax.plot(angles, values, linewidth = 1, linestyle = 'solid', color=colors_type[t], label = t)
        # Pintando a área interna do polígono
        ax.fill(angles, values, colors_type[t], alpha=0.3)
        # Inserindo legendas
        plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
    ax.set_title(title)

# %%
radarPlot(['Dragon'], mean_by_type)

# %%
radarPlot(['Steel'], mean_by_type)

# %%
radarPlot(['Flying'], mean_by_type)

# %%
radarPlot(['Fire', 'Water', 'Grass'], mean_by_type)

# %% [markdown]
# <p>Sobre os 3 tipos de pokemon inicial podemos notar que fogo tem mais vantagem em Velocidade, Ataque Especial e Ataque. Já os pokemons de planta são mais equilibrados, ganhando por pouco em Ataque especial de água. Com essa análise poderíamos optar mais por pokemons de Fogo pois, provavelmente, seria o pokemon inicial mais forte.</p>
